# %% [markdown]
# <a href="https://colab.research.google.com/github/vedina0904/final-exam-Vedina-Runghen/blob/main/final_exam_vedina_runghen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Section 1 - Prompt 1
#
# I have an assignment to do. Here is what I did below
# Week 1: Getting Started with Python, AI, and Essential Tools Set up Google Colab and GitHub, write your first Python code with print(), and learn the role of AI in beginner programming workflows.
# Week 2: Personalising Data: The User Preferences Project Capture user input, store it in variables, and build a custom interaction tool powered by personal data and logic. Here is the question: Basic lists and dictionaries for data storage
# Week 3: Weather Forecaster with Python Logic Use if, elif, and else to build a decision-making script. Learn how programs respond to different user inputs.
# Week 4: Unlocking Reusability – Functions & Modules Break code into reusable parts with custom functions. Learn to import modules and refactor your weather app for maintainability.
# Week 5: Lists & Loops – Understanding Collections Learn how to manage collections with Python lists and repeat tasks using loops. A critical week for automation and data processing.
# Week 6: Python Dictionaries – Smart Data Structures Use dictionaries to store, access, and structure data efficiently. This week bridges technical and business problem solving.
# Week 7: Business Data Processing Turn raw input into structured summaries using loops and built-ins. Simulate basic analytics and dashboard logic.
# Week 8: APIs and External Data Fetch live data from APIs, work with JSON, and display real-time content in your Python apps. A key week for your final project.
# Week 9: Tuition-Free Week No scheduled classes. Time to revise, reflect, and polish your work. Reach out if you need help!
# Week 10: Object Oriented Programming Build Python classes to encapsulate logic. Learn OOP fundamentals like constructors, methods, and object reuse.
#
# Here is the question: Your pseudocode must reflect only techniques taught through to Week 10: Basic lists and dictionaries for data storage • Simple functions with parameters • Basic file operations (if needed for persistence) • While loops for menu systems • Try/except for basic error handling only

# %%
AI RESPONSE:

START
# Define a dictionary to store tasks
tasks = {}

# Define a function to display the main menu
FUNCTION show_menu():
    PRINT "====== Task Manager ======"
    PRINT "1. Add Task"
    PRINT "2. List Tasks"
    PRINT "3. Remove Task"
    PRINT "4. Exit"

# Define a function to add a task
FUNCTION add_task():
    INPUT "Enter task ID:" → task_id
    INPUT "Enter task description:" → description
    tasks[task_id] = description
    PRINT "Task added successfully!"

# Define a function to list all tasks
FUNCTION list_tasks():
    IF tasks IS EMPTY:
        PRINT "No tasks available."
    ELSE:
        FOR each task_id IN tasks:
            PRINT task_id + ": " + tasks[task_id]

# Define a function to remove a task
FUNCTION remove_task():
    INPUT "Enter task ID to remove:" → task_id
    IF task_id IN tasks:
        DELETE tasks[task_id]
        PRINT "Task removed."
    ELSE:
        PRINT "Task ID not found."

# Main loop using while
FUNCTION main():
    WHILE True:
        show_menu()
        TRY:
            INPUT "Choose an option (1-4):" → choice
            IF choice == "1":
                add_task()
            ELIF choice == "2":
                list_tasks()
            ELIF choice == "3":
                remove_task()
            ELIF choice == "4":
                PRINT "Exiting Task Manager. Goodbye!"
                BREAK
            ELSE:
                PRINT "Invalid option. Please choose 1-4."
        EXCEPT:
            PRINT "An error occurred. Try again."

# Run the program
main()

COURSE CONSTRAINT CHECK:
I'm forced to manually add the ID of the task,
There is no date in the task.
there is no flag stating the status of the task (done/pending/undone)

# %% [markdown]
# 1.1 - Prompt 2:
# I want it to automatically add the ID, today's date and a flag to say if it's done or not to the task.

# %%
AI RESPONSE:

IMPORT datetime module  # For getting today's date

# Initialize a list to store tasks (each task is a dictionary)
tasks = []
task_id_counter = 1  # Global counter to assign unique IDs

# Define function to display the main menu
FUNCTION show_menu():
    PRINT "====== Task Manager ======"
    PRINT "1. Add Task"
    PRINT "2. List Tasks"
    PRINT "3. Remove Task"
    PRINT "4. Mark Task as Done"
    PRINT "5. Exit"

# Define function to add a new task
FUNCTION add_task():
    GLOBAL task_id_counter
    INPUT "Enter task description:" → description
    SET current_date = today's date (e.g., use datetime.today().strftime('%Y-%m-%d'))
    CREATE task = {
        "id": task_id_counter,
        "description": description,
        "date": current_date,
        "done": False
    }
    APPEND task TO tasks
    INCREMENT task_id_counter
    PRINT "Task added successfully!"

# Define function to list all tasks
FUNCTION list_tasks():
    IF tasks IS EMPTY:
        PRINT "No tasks available."
    ELSE:
        FOR each task IN tasks:
            PRINT "ID:", task["id"]
            PRINT "Description:", task["description"]
            PRINT "Date:", task["date"]
            PRINT "Completed:", task["done"]
            PRINT "----------------------"

# Define function to remove a task
FUNCTION remove_task():
    INPUT "Enter task ID to remove:" → id_to_remove
    SET found = False
    FOR each task IN tasks:
        IF task["id"] == id_to_remove:
            REMOVE task FROM tasks
            found = True
            PRINT "Task removed."
            BREAK
    IF NOT found:
        PRINT "Task ID not found."

# Define function to mark task as done
FUNCTION mark_task_done():
    INPUT "Enter task ID to mark as done:" → id_to_mark
    SET found = False
    FOR each task IN tasks:
        IF task["id"] == id_to_mark:
            task["done"] = True
            found = True
            PRINT "Task marked as completed."
            BREAK
    IF NOT found:
        PRINT "Task ID not found."

# Main loop using while
FUNCTION main():
    WHILE True:
        show_menu()
        TRY:
            INPUT "Choose an option (1-5):" → choice
            IF choice == "1":
                add_task()
            ELIF choice == "2":
                list_tasks()
            ELIF choice == "3":
                remove_task()
            ELIF choice == "4":
                mark_task_done()
            ELIF choice == "5":
                PRINT "Exiting Task Manager. Goodbye!"
                BREAK
            ELSE:
                PRINT "Invalid option. Please choose 1-5."
        EXCEPT:
            PRINT "An error occurred. Try again."

# Run the program
main()

# %% [markdown]
# # 1.2 - Prompt 3
#
# I want to list the tasks by the following:
# done, undone, pending, ASC date, DES date and try catch input error handling. Build Python classes to encapsulate logic. Learn OOP fundamentals like constructors, methods, and object reuse.
#
# AI RESPOND:
#
# from datetime import datetime
#
# # Task class to store individual task details
#
# class Task:
#     def __init__(self, id, description):
#         self.id = id
#         self.description = description
#         self.date = datetime.today().strftime("%Y-%m-%d")
#         self.done = False
#
#     def mark_done(self):
#         self.done = True
#
#     def __str__(self):
#         return f"ID: {self.id} | {self.date} | Done: {self.done} | Description: {self.description}"
#
#
# # TaskManager class to manage the task list
#
# class TaskManager:
#     def __init__(self):
#         self.tasks = []
#         self.task_id_counter = 1
#
#     def add_task(self):
#         description = input("Enter task description: ")
#         task = Task(self.task_id_counter, description)
#         self.tasks.append(task)
#         print("✅ Task added!")
#         self.task_id_counter += 1
#
#     def list_tasks(self, mode="all"):
#         filtered = []
#         today = datetime.today().strftime("%Y-%m-%d")
#
#         if mode == "done":
#             filtered = [task for task in self.tasks if task.done]
#         elif mode == "undone":
#             filtered = [task for task in self.tasks if not task.done]
#         elif mode == "pending":
#             filtered = [task for task in self.tasks if not task.done and task.date < today]
#         elif mode == "asc":
#             filtered = sorted(self.tasks, key=lambda t: t.date)
#         elif mode == "desc":
#             filtered = sorted(self.tasks, key=lambda t: t.date, reverse=True)
#         else:
#             filtered = self.tasks
#
#         if not filtered:
#             print("⚠️ No tasks to show.")
#         else:
#             print("\n--- Task List ---")
#             for task in filtered:
#                 print(task)
#             print("------------------")
#
#     def remove_task(self):
#         try:
#             task_id = int(input("Enter Task ID to remove: "))
#             for task in self.tasks:
#                 if task.id == task_id:
#                     self.tasks.remove(task)
#                     print("🗑️ Task removed.")
#                     return
#             print("❌ Task not found.")
#         except ValueError:
#             print("⚠️ Invalid input. Please enter a valid number.")
#
#     def mark_task_done(self):
#         try:
#             task_id = int(input("Enter Task ID to mark as done: "))
#             for task in self.tasks:
#                 if task.id == task_id:
#                     task.mark_done()
#                     print("✅ Task marked as done.")
#                     return
#             print("❌ Task not found.")
#         except ValueError:
#             print("⚠️ Invalid input. Please enter a valid number.")
#
#     def show_menu(self):
#         print("\n====== Task Manager ======")
#         print("1. Add Task")
#         print("2. List All Tasks")
#         print("3. List Done Tasks")
#         print("4. List Undone Tasks")
#         print("5. List Pending Tasks")
#         print("6. List Tasks by Date (ASC)")
#         print("7. List Tasks by Date (DESC)")
#         print("8. Mark Task as Done")
#         print("9. Remove Task")
#         print("10. Exit")
#
#     def run(self):
#         while True:
#             self.show_menu()
#             try:
#                 choice = int(input("Enter your choice (1–10): "))
#                 if choice == 1:
#                     self.add_task()
#                 elif choice == 2:
#                     self.list_tasks()
#                 elif choice == 3:
#                     self.list_tasks("done")
#                 elif choice == 4:
#                     self.list_tasks("undone")
#                 elif choice == 5:
#                     self.list_tasks("pending")
#                 elif choice == 6:
#                     self.list_tasks("asc")
#                 elif choice == 7:
#                     self.list_tasks("desc")
#                 elif choice == 8:
#                     self.mark_task_done()
#                 elif choice == 9:
#                     self.remove_task()
#                 elif choice == 10:
#                     print("👋 Exiting Task Manager.")
#                     break
#                 else:
#                     print("⚠️ Invalid choice. Please choose from 1 to 10.")
#             except ValueError:
#                 print("⚠️ Invalid input. Please enter a number.")
#
#
# # Run the program
# if __name__ == "__main__":
#     tm = TaskManager()
#     tm.run()
#
#
# Course reference:

# %% [markdown]
# **Section 2: Debug & Correct with AI (25 marks)**
#
# The Buggy Code
#
# Prompt 1 -
#
# How would you go about methodically finding and resolving the numerous errors in the broken_task_manager.py script, such as typos, incorrect variable references, and incorrect function calls, using a combination of conventional debugging techniques (such as print statements and IDE debuggers) and AI-assisted tools?  In addition, how might you create and execute unittest or doctest test cases to address these issues and guarantee strong task management function validation? How AI could help create these tests and increase the effectiveness of debugging, particularly in identifying minor problems like function call failures and variable name mismatches.

# %%
2.1 Error Identification

Identify and Fix Errors in the Code
Error 1: if index < len(tas):

tas should be tasks (typo).

Error 2: for i, t in enumerate(task):

task should be tasks (wrong variable name).

Error 3: list_task() in main()

Should be list_tasks() (function call typo).

AI RESPONSE;

tasks = []

def add_task(task):
    """
    Adds a task to the task list.

    >>> add_task("Buy milk")
    Added: Buy milk
    >>> tasks[-1]
    'Buy milk'
    """
    tasks.append(task)
    print(f"Added: {task}")

def remove_task(index):
    """
    Removes a task at the given index from the task list.

    >>> add_task("Test Task")
    Added: Test Task
    >>> remove_task(0)
    Removed: Test Task
    """
    if index < len(tasks):  # Fixed typo: 'tas' -> 'tasks'
        removed = tasks[index]
        del tasks[index]
        print(f"Removed: {removed}")
    else:
        print("Invalid index!")

def list_tasks():
    """
    Lists all tasks with their index.

    >>> add_task("Sample Task")
    Added: Sample Task
    >>> list_tasks()
    1: Sample Task
    """
    if not tasks:
        print("No tasks available.")
    else:
        for i, t in enumerate(tasks):  # Fixed variable name: 'task' -> 'tasks'
            print(f"{i+1}: {t}")

def main():
    add_task("Buy milk")
    add_task("Pay bills")
    add_task("Walk dog")
    list_tasks()
    remove_task(1)
    list_tasks()  # Fixed function name: 'list_task()' -> 'list_tasks()'

if __name__ == "__main__":
    main()


2.2 Fix & Manual Rewrite

tasks =

def add_tas(task):
"""
Adds a task to the task list.

>>>tasks.clear()
>>>add_task("Buy milk")
Added: Buy milk
>>> tasks
['Buy milk']
"""

task.append(task)
print(f"Added:{task}")

def remove_task(index):
"""
Removes a task at the given from the task list.

>>>tasks.clear()
>>>add_task("Task 1")
Added: Task 2
>>>tasks
['Task 2']
>>>remove_task(5)
Invalid index!
"""

if index <len(tasks): # Fixed typo from 'tas'
removed = tasks[index]
del tasks[index]
print(f'Removed:{removed}")
  else:
    print("invalid index!")

def list_tasks():
  """
  Lists all current tasks.

  >>>tasks.clear()
  >>>add_current("study")
  Added: Study
  >>>list_tasks()
  1: Study
  >>>tasks.clear()
  >>>list_tasks()
  No tasks available.
  """
  if not tasks:
    if not tasks:
      print("No tasks available")
    else
      for i, t in enumerate(tasks): # Fixed wrong variable 'task' -> 'tasks'
        print(f"{i+1}:(t)")

  def main():
  """
  Demonstrastes basic task manager functions.
  Not meant for doctest (inteaction only)
  """

  add_task("Buy milk")
  add_task("Pay bills")
  add_task("Water the plant")
  list_tasks()
  remove_task(1)
  list_tasks() #Fixed wrong function name 'list_task' -> 'list_tasks'

  if_name_=="_main_"
    import doctest
    doctest.testmod() #This runs all the doctests
    main()

# %% [markdown]
# 3.1 Issue Analysis with Course Connection
#
# 1: the except clause
# except:
#         reuturn "Error occurred"
#
# it catches all exceptions, including ones that shoud notbe silently
# handled (like systemExit)
#
# This makes the debugging harder and can hide serious issues.
#
# 2: No Input validation
# the url = f"http://wttr.in/{city}?format=1"
#
# The function does not check if city is a valid, non-empty string.
# If an emtpy or None is passed, the request may fail or return misleading results.
#
# 3: No HTTP status code check.
# response = requests.get(url)
# data = response.json()
#
# It does not check response.status_code before trying to parse JSON.
# If the server returns an error (e.g: 404 or 500), response.json() might raise an exception.
#
# What’s acceptable (based on Week 8 / introductory concepts):
# 	1.	Use of try/except block:
# 	•	It’s correctly used to catch errors and prevent the program from crashing.
# 	2.	Returning a fallback value on error:
# 	•	Returning "Error occurred" provides a basic way to signal failure to the caller.
#
#
#
#  What needs improvement (within Week 8 constraints):
# 	1.	No input check for empty city name
# 	•	Issue: If city is an empty string, the URL becomes http://wttr.in/?format=j1, which can give unexpected results.
# 	•	Fix (allowed by Week 8 knowledge):
#
#
#
# if not city:
#     return "Error: city name is empty"
#
#
# 2.	Bare except clause
# 	•	Issue: It catches everything, including system-level exceptions.
# 	•	Fix (within Week 8 limits): Even though we’re not doing fine-grained error types yet, it’s still better to print a meaningful error message:
#
# except:
#     return "Error: could not fetch or parse data"
#
# 3.	 No validation of the HTTP response
# •	Issue: If the HTTP response is not 200 OK, response.json() might still run and fail.
# •	Fix (simple check allowed in Week 8):
#
# if response.status_code != 200:
#     return "Error: failed to fetch data"

# %%
Rewritten version (sticking strictly to Week 8 level):

import requests

def safe_weather_data_fetch(city):
    """Fetch weather data for a city from wttr.in API - Week 8 version"""
    if not city:
        return "Error: city name is empty"

    try:
        url = f"http://wttr.in/{city}?format=j1"
        response = requests.get(url)
        if response.status_code != 200:
            return "Error: failed to fetch data"

        data = response.json()
        weather_info = {
            'city': city,
            'temperature': data['current_condition'][0]['temp_C'],
            'wind_speed': data['current_condition'][0]['windspeedKmph'],
            'description': data['current_condition'][0]['weatherDesc'][0]['value']
        }
        return weather_info
    except:
        return "Error: could not fetch or parse data"

# %%
3.2: Function Refinement with Course Constraints
1:
import requests

def refined_safe_weather_data_fetch(city):
    """
    Fetches weather data for a given city using wttr.in API.

    Returns a dictionary with temperature, wind speed, and description,
    or None if an error occurs.

    Parameters:
    city (str): The name of the city to fetch weather for.

    Returns:
    dict or None: Weather data dictionary or None on failure.

    Examples (doctest format):

    >>> result = refined_safe_weather_data_fetch("London")
    >>> isinstance(result, dict)
    True
    >>> "temperature" in result
    True
    >>> "wind_speed" in result
    True

    >>> refined_safe_weather_data_fetch("")
    Error: city name cannot be empty
    >>> refined_safe_weather_data_fetch("") is None
    True

    >>> refined_safe_weather_data_fetch("InvalidCityNameExample12345") is None or isinstance(_, dict)
    True
    """
    if not city:
        print("Error: city name cannot be empty")
        return None

    try:
        url = f"http://wttr.in/{city}?format=j1"
        response = requests.get(url)
        if response.status_code != 200:
            print("Error: failed to fetch data from server")
            return None

        data = response.json()
        weather_info = {
            'city': city,
            'temperature': data['current_condition'][0]['temp_C'],
            'wind_speed': data['current_condition'][0]['windspeedKmph'],
            'description': data['current_condition'][0]['weatherDesc'][0]['value']
        }
        return weather_info

    except:
        print("Error: could not process weather data")
        return None

2:

import requests

def refined_safe_weather_data_fetch(city):
    """
    Fetch weather data with basic error handling - Week 8 style

    >>> refined_safe_weather_data_fetch("")
    Error: City name cannot be empty

    >>> refined_safe_weather_data_fetch("InvalidCity123") # doctest: +SKIP
    Error: Could not connect to weather service

    >>> result = refined_safe_weather_data_fetch("London") # doctest: +SKIP
    >>> isinstance(result, dict)
    True
    """
    if not city:
        print("Error: City name cannot be empty")
        return None

    try:
        url = f"http://wttr.in/{city}?format=j1"
        response = requests.get(url)
        data = response.json()

        weather_info = {
            'city': city,
            'temperature': data['current_condition'][0]['temp_C'],
            'wind_speed': data['current_condition'][0]['windspeedKmph'],
            'description': data['current_condition'][0]['weatherDesc'][0]['value']
        }

        return weather_info

    except:
        print("Error: Could not connect to weather service")
        return None

# %% [markdown]
# **3.3: Comparison Analysis **
#
# Comparison Analysis: refined_safe_weather_data_fetch vs. Ideal Version
#
# 1. Similarities (Basic approaches both versions share):
#
# 1.1 Use of try/except for error handling:
#     Both functions use a basic try/except block to catch general errors and prevent the program from crashing when network or parsing issues occur.
#
# 1.2 Input validation for empty city name:
#     Each version checks if the city input is empty using a simple `if not city:` condition and prints an error message accordingly.
#
# 2. Differences (How they handle complexity differently):
#
# 2.1 Error messaging placement:
#     - The ideal version prints different error messages for different stages: connection errors vs. data extraction errors.
#     - The refined version handles all failures (except empty input) with a single, general message: "Error: Could not connect to weather service".
#
# 2.2 Nested error handling in data parsing:
#     - The ideal version uses a nested try/except block to safely extract fields from the response JSON.
#     - The refined version parses the data inside a single block without protecting the field access step, which is simpler but less robust.
#
# 3. Course Connection (Week 8 concept demonstrated best):
#
# Simple, single try/except error handling:
#     The refined version strongly demonstrates Week 8’s core concept: wrapping risky code in a try/except block to catch errors without using advanced exception types or logic.

# %% [markdown]
# 4. Improvement Area (based on Textbook Chapter 6):
#
# Improve data parsing safety:
#     Chapter 6 emphasizes writing more defensive code. After reviewing it, a good improvement would be to safely access nested data (e.g., checking if 'current_condition' and 'temp_C' exist before accessing them), possibly using if conditions or breaking the parsing into smaller steps.

# %%
4.1:Manual Implementation with Course Constraints

# Week 4-6 Task Manager Implementation

def display_menu():
    """
    Display menu options - use Week 3 formatting techniques only

    >>> display_menu() # doctest: +SKIP
    1. Add task
    2. List tasks
    3. Remove task
    4. Quit
    """
    print("1. Add task")
    print("2. List tasks")
    print("3. Remove task")
    print("4. Quit")

def get_user_choice():
    """
    Get and validate user choice - Week 6 input validation style

    >>> # Manual test expected due to input()
    >>> # get_user_choice() # doctest: +SKIP
    """
    while True:  # Week 5 loop pattern: basic while loop with condition
        choice = input("Enter your choice (1-4): ")  # Week 4: basic input()
        if choice in ["1", "2", "3", "4"]:  # Week 6: simple input validation
            return choice
        else:
            print("Invalid choice. Please enter a number from 1 to 4.")

def main():
    """Main programme loop - Week 5 loop patterns only"""
    tasks = []  # Week 4: simple list initialization

    while True:  # Week 5: menu loop pattern
        display_menu()
        choice = get_user_choice()

        if choice == "1":
            task = input("Enter a new task: ")  # Week 4: basic input()
            tasks.append(task)  # Week 4: list append
            print("Task added.")
        elif choice == "2":
            if not tasks:
                print("No tasks available.")
            else:
                for i, task in enumerate(tasks):  # Week 4: loop with enumerate
                    print(f"{i + 1}. {task}")
        elif choice == "3":
            if not tasks:
                print("No tasks to remove.")
            else:
                for i, task in enumerate(tasks):
                    print(f"{i + 1}. {task}")
                try:
                    index = int(input("Enter task number to remove: "))
                    if 1 <= index <= len(tasks):  # Week 6: basic input range validation
                        removed = tasks.pop(index - 1)
                        print(f"Removed: {removed}")
                    else:
                        print("Invalid number.")
                except:
                    print("Invalid input. Please enter a number.")
        elif choice == "4":
            print("Goodbye!")
            break

# %% [markdown]
# 1. Workflow Balance with Course Learning
# In implementing the functions, I applied strategies discussed in the Week 5 slides on Human-AI Collaboration. I handled planning and pseudocode manually, then used AI to accelerate the translation into code, ensuring it remained within Week 4-6 lab constraints. This aligns with our lecture’s principle: humans design logic and context; AI helps execute low-level tasks. I used human review to refine AI-generated code, avoiding forbidden techniques from the Week 8 style guide.
#
# 2. Course Concept Application
# While writing refined_safe_weather_data_fetch, I used the “Error Handling Mindset” from Week 8 by anticipating failure during API calls and returning None safely. I also applied “Defensive Programming” by validating empty inputs (if not city) before executing logic. This connected directly to my experience in doctest-based testing (Week 9)—both concepts helped ensure consistent function behavior and testability even when input was incorrect or external calls failed.
#
# 3. Learning Transfer
# For the final project, I’ll apply the iterative refinement process (Week 6) to break tasks into manageable steps, testing each version. From Assignment 2 feedback, I learned my input validation was too weak. I’ll now improve it using the basic validation + user prompt loop pattern we practiced in Lab 5, ensuring more robust user interaction in future iterations.
